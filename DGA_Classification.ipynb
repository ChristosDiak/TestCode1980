# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristosDiak/TestCode1980/blob/main/DGA_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#εγκατάσταση πακέτου pycaret (https://pycaret.org/)
# !pip install pycaret
#***ΠΡΟΣΟΧΗ*** μετά την εγκατάσταση χρειάζεται restart το session
#***θα σας ζητηθεί επανεκκίνηση με σχετικό κόκκινο μήνυμα μετά την ολοκλήρωση της εγκατάστασης
#***Πατήστε το κουμπί RESTART SESSION στο σχετικό μήνυμα

# %%
#εισαγωγή βιβλιοθηκών - πακέτων
import pycaret
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1744/1440502464.py in <cell line: 0>()
#       1 #εισαγωγή βιβλιοθηκών - πακέτων
# ----> 2 import pycaret
#       3 import pandas as pd
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# /usr/local/lib/python3.12/dist-packages/pycaret/__init__.py in <module>
#      20     )
#      21 elif sys.version_info >= (3, 12):
# ---> 22     raise RuntimeError(
#      23         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      24         sys.version_info,
#
# RuntimeError: ('Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ', sys.version_info(major=3, minor=12, micro=13, releaselevel='final', serial=0), 'Please DOWNGRADE your Python version.')

# %%
#εισαγωγή του συνόλου δεδομένων
url = 'https://raw.githubusercontent.com/kdemertzis/EKPA/main/Data/dga_2class.csv'
df = pd.read_csv(url)
#έλεγχος σχήματος συνόλου δεδομένων
print(df.shape)

# %%
#ανακάτεμα των δεδομένων
df = df.sample(frac = 1)
print(df.head())

# %%
#εγκατάσταση του συνόλου δεδομένων
grid = setup(data=df, target=df.columns[-1], html=False, verbose=False)

# %%
#σύγκριση των διαθέσιμων μοντέλων ΜΜ
best = compare_models(cross_validation=False, n_select = 1)
# %load_ext tensorboard

# %%
#αναφορά των υπερπαραμέτρων του μοντέλου με την υψηλότερη απόδοση
print(best)

# %%
#μέτρα αξιολόγησης του μοντέλου με την υψηλότερη απόδοση
evaluate_model(best)
